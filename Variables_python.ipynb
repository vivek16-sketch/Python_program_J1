# %% [markdown]
# # Variables In python
# 1. variables is memory allocation to value
# 2. examples are name="vivek", age=26, salary=20000.65
#
# ## key points to define variables
# 1. variable do not start with digit
# 2. variable does not allowed special characters
# 3. do not use keywords as a variables

# %%
name="vivek"
age=20
salary=45000.65
print(name)
print(age)
print(salary)

# %%
1name="vivek"
print(name)

# %%
name@="vivek"
print(while)

# %%
while = "vivek"
print(while)

# %%
while1 =
